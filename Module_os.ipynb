# %%
#合并目录
 
import os
os.path.join('/hello/','good/boy/','doiido')
# Out:
# '/hello/good/boy/doiido'

# %%
os.getcwd()
os.listdir()
os.remove('file')
os.removedir()
os.path.isfile #if it's a file
os.path.isdir #if it's a directory
os.path.exists

dirname, filename = os.path.split('users\dggg\dg') #分离文件名、扩展名
fname, fename = os.path.splitext('\ett\trf\gg') 

os.path.dirname('\dg\sdg\s') #获得pathname 文件路径
os.path.basename('\ddfg\dfa\sd') #获得文件名
os.getenv #获得当前环境

# %%
with open('/Users/rachelwang/cmddemo/demo.txt', 'r') as f:
    c = f.read()
print(c)
# Out:
# <session:62>	C	(2017-12-09 15:10:27)	我想问问这个包可以装进15寸电脑不	0.9999	false
# <session:134>	C	(2017-11-05 16:00:40)	请问这个包15寸电脑勉强能放吗	1.0000	false
# <session:279>	S	(2017-11-10 23:38:50)	您好亲，ACE书包的电脑夹层大部分是可以容纳14寸电脑哈，有一些小款可以放12寸、10寸电脑哦（详情都会说明）；很多亲们的反馈是可以放下自己偏薄一点的15寸电脑，因电脑种类众多，不能一 一列举给亲，您可以通过电脑的尺寸和书包的详细尺寸对比选择哦；ACE支持7天无理由退换货，请亲放心选购~ /:-f
# <session:284>	S	(2017-12-12 09:16:51)	您好亲，ACE书包的电脑夹层大部分是可以容纳14寸电脑哈，有一些小款可以放12寸、10寸电脑哦（详情都会说明）；很多亲们的反馈是可以放下自己偏薄一点的15寸电脑，因电脑种类众多，不能一 一列举给亲，您可以通过电脑的尺寸和书包的详细尺寸对比选择哦；ACE支持7天无理由退换货，请亲放心选购~ /:-f
# <session:328>	S	(2017-11-27 20:31:35)	您好亲，ACE书包的电脑夹层大部分是可以容纳14寸电脑哈，有一些小款可以放12寸、10寸电脑哦（详情都会说明）；很多亲们的反馈是可以放下自己偏薄一点的15寸电脑，因电脑种类众多，不能一 一列举给亲，您可以通过电脑的尺寸和书包的详细尺寸对比选择哦；ACE支持7天无理由退换货，请亲放心选购~ /:-f
# <session:552>	S	(2017-12-11 23:16:36)	您好亲，ACE书包的电脑夹层大部分是可以容纳14寸电脑哈，有一些小款可以放12寸、10寸电脑哦（详情都会说明）；很多亲们的反馈是可以放下自己偏薄一点的15寸电脑，因电脑种类众多，不能一 一列举给亲，您可以通过电脑的尺寸和书包的详细尺寸对比选择哦；ACE支持7天无理由退换货，请亲放心选购~ /:-f
# <session:995>	C	(2017-11-29 18:13:37)	你家有能放15寸电脑的包包吗	1.0000	false
# ...
